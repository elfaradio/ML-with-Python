# %%
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3, 4, 5]
y = [3, 1, 3, 5, 4]
plt.plot(x, y)
plt.xticks(x)  # x axis change
plt.xlim(0, 10)  # limit x
plt.axis([0, 10, 0, 20])  # same xlim
plt.show()
