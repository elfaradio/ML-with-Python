# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
x = np.random.randint(10, 60, 50)
n = x

l = [10, 20, 30, 40, 50, 60]
plt.hist(n, rwidth=2,  bins=l, color="g", edgecolor="r")

# bottom=10 y 10 theke hobe start
# orientation=Vertical,horizontal
# rwidth=

# log=True

# label= Go

# align="left"

# histtype="step",stepfilled,barstacked,bar,

# cumulative=-1 reverse

# plt.hist(n, "auto", (0, 100), color="g", edgecolor="r")
plt.title("Farhad")

plt.xlabel("Go")

plt.grid()  # for grid


plt.axvline(40, color="y", label="gdkj")  # a line in40
plt.legend()  # must be for label
plt.show()
