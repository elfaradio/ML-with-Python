# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = ["python", "c", "c++", "Java"]
y = [85, 70, 60, 82]
z = [20, 30, 40, 50]

width = 0.2
p = np.arange(len(x))
p1 = [j+0.2 for j in p]

plt.xlabel("Language", fontsize=15)
plt.ylabel("No.", fontsize=15)
plt.title("Frad", fontsize=15)

# barh
plt.bar(p, y, width, color="r", label="fraaaaaaaaad")
plt.bar(p1, z, width, color="y", label="fraaaaaaaad1")

plt.xticks(p + width / 2, x, rotation=20)
plt.legend()
plt.show()
