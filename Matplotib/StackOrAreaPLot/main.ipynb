# %%
import matplotlib.pyplot as plt

import numpy as np

# %%
x = [12, 13, 144]
y = [2, 3, 5]
z = [8, 4, 10]
zz = [10, 12, 22]
ll = ["x", "y", "z", "zz"]

# colors=[]  for color

# baseline="sym",wiggle nich theke cut

plt.stackplot(x, y, z, zz, labels=ll)
plt.legend(loc=2)

plt.show()
