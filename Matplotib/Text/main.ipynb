# %%
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3, 4]
y = [5, 6, 7, 10]
plt.plot(x, y)

plt.title("ML")
plt.xlabel("M")
plt.ylabel("L")
# plt.text(2, 9, "fghdj")
plt.annotate("hjx", xy=(3, 2), xytext=(4, 4), arrowprops=(
    dict(facecolor="black", shrink=1000)))
plt.show()
