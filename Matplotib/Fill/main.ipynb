# %%
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3, 4, 5]
y = [1, 2, 3, 4, 5]
plt.plot(x, y)
plt.fill_between(x=[2, 4], y1=2, y2=5, where=(x > 2) & (x < 4))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       2 y = [1, 2, 3, 4, 5]
#       3 plt.plot(x, y)
# ----> 4 plt.fill_between(x=[2, 4], y1=2, y2=5, where=(x > 2))
#       5 plt.show()
#
# TypeError: '>' not supported between instances of 'list' and 'int'
