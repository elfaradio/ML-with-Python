# %%
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3, 4, 5]

plt.boxplot(x, patch_artist=True)  # 3 is mediam where yellow line occur

# 1 and 5 whisker plot

# notch=True v shape

# vert=True,false

# widths=0.7

# labels=["a"]

# patch_artist=True fill by color

# for outler last value-[n-1] is bigger

# sym="g+" outer color and shape

# whist =2 connect with outer

# showmeans=True   trainlge in means or 3

# boxprops=dict(color="r),cappross=dict(color="g"),whiskerprops

# fillerprops=dict(markeredgecolor="y")

# plt.boxplot(x, y)

plt.show()
