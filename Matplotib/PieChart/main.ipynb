# %%
import matplotlib.pyplot as plt

import numpy as np

import random

# %%
x = [1, 2, 3, 4, 5]

y = ["a", "b", "c", "d", "e"]

ex = [0.2, 0.9, 0.0, 0.0, 0.0]  # bairer dike dekhanor jonno

# c=[],colors=c

# autopct"%0.1f%%" for percantage

# shadow=True for shadow

# radius=1.5

# labeldistance for label

# startangle=90


# textprops={"fontsize":15}

# counterclock=false  --  rotate

# wedgeprops={"linewidth":4,width,edgecolor}

# center=(1,3)

# rotatelabel=true


plt.pie(x, labels=y, autopct="%0.1f%%", explode=ex, shadow=True)

plt.title("Frad")

plt.legend(loc=10)

# plt.pie([1])

plt.show()

# %%
plt.pie([1, 2, 3, 4], labels=["a", "b", "c", "s"], radius=1.5)

plt.pie([1], colors="w")
plt.show()

# %%
plt.pie([1, 2, 3, 4], labels=["a", "b", "c", "s"], radius=1.5)

cr = plt.Circle(xy=(0, 0), radius=1, facecolor="w")
plt.gca().add_artist(cr)
plt.show()
